# %% [markdown]
# <a href="https://colab.research.google.com/github/samuel-apls/curso-python-gustavo-guanabra/blob/main/Python_Mundo_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ex000**
#
# Exercício de exemplo

# %%
print('Olá, Mundo!')

# %% [markdown]
# **ex001**
#
# Crie um programa que escreva "Olá, Mundo!" na tela.

# %%
msg = 'Olá, Mundo!'
print(msg)
