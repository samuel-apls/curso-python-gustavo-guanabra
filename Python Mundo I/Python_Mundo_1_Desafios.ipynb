# %%
<a href="https://colab.research.google.com/github/samuel-apls/curso-python-gustavo-guanabra/blob/main/Python_Mundo_1_Desafios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Desafio 001 - Deixando tudo pronto**
#
# Crie um script Python que leia o nome de uma pessoa e mostra uma mensagem de boas-vindas.

# %%
nome = input('Qual é seu nome? ')
print('Olá, {}! Prazer em te conhecer!'.format(nome))

# %% [markdown]
# **Desafio 002 - Respondendo ao usuário**
#
# Crie um script Python que leia o dia, mês e o ano de nascimento de uma pessoa e mostra uma mensagem com a data formatada.

# %%
dia = int(input('Digite o dia do seu nascimento: '))
mes = int(input('Digite o mês do seu nascimento: '))
ano = int(input('Digite o ano do seu nascimento: '))
print('Sua data de nascimento é: {}/{}/{}'.format(dia, mes, ano))

# %% [markdown]
# **Desafio 003 - Somando dois números**
#
# Crie um programa que leia dois números e mostra a soma entre eles

# %%
n1 = int(input('Digite um número: '))
n2 = int(input('Digite outro número: '))
print('A soma entre {} e {} é {}'.format(n1, n2, n1 + n2))

# %% [markdown]
# **Desafio 004 - Dissecando uma variável**
#
# Faça um programa que leia algo pelo teclado e mostra na tela seu tipo primitivo e todas as informações possíveis sobre ela

# %%
v = input('Digite algo: ')
print('Seu tipo primitivo é {}'.format(type(v)))
print('É numérico: {}'.format(v.isnumeric()))
print('É alfanúmerico: {}'.format(v.isalnum()))
print('É alfabético: {}'.format(v.isalpha()))
print('Está em maiúsculo: {}'.format(v.isupper()))
# Out:
# Digite algo: algo
# Seu tipo primitivo é <class 'str'>
# É numérico: False
# É alfanúmerico: True
# É alfabético: True
# Está em maiúsculo: False

# %% [markdown]
# **Desafio 005 - Antecessor e sucessor**
#
# Faça um programa que leia um número inteiro e mostra na tela seu sucessor e antecessor

# %%
numero = int(input('Digite um número: '))
print(f'Antecessor: {numero - 1}')
print(f'Sucessor: {numero + 1}')
# Out:
# Digite um número: 1
# Antecessor: 0
# Sucessor: 2

# %% [markdown]
# **Desafio 006 - Dobro, Triplo, Raiz quadrada**
#
# Crie um algoritmo que leia um número e mostre o seu dobro, triplo e raíz quadrada

# %%
numero = float(input('Digite um número: '))
print(f'Dobro: {numero * 2:.0f}')
print(f'Triplo: {numero * 3:.0f}')
print(f'Raiz quadrada: {numero ** 1/2:.0f}')
# Out:
# Digite um número: 5
# Dobro: 10
# Triplo: 15
# Raiz quadrada: 25

# %% [markdown]
# **Desafio 007 - Média aritmética**
#
# Desenvolva um programa que leia as duas notas de um aluna, calcule mostre a sua média

# %%
nota1 = float(input('Primeira nota: '))
nota2 = float(input('Segunda nota: '))
media = (nota1 + nota2) / 2
print(f'Média: {media:.2f}')
# Out:
# Primeira nota: 3
# Segunda nota: 2.5
# Média: 2.75

# %% [markdown]
# **Desafio 008 - Conversor de medidas**
#
# Escreva um programa que leia um valor em metros e o exiba convertido em centimetros e milímetros

# %%
metro = float(input('Digite o valor me metros: '))
centimetro = metro * 100
print(f'Conversão para centímetros: {centimetro:.2f}')
# Out:
# Digite o valor me metros: 1
# Conversão para centímetros: 100.00

# %% [markdown]
# **Desafio 009 - Tabuada**
#
# Fala um programa que leia um número inteiro qualquer e mostre na tela a sua tabuada

# %%
numero = int(input('Digite um número: '))
i = 1
while i <= 10:
    print(f'{numero} x {i} = {numero * i}')
    i += 1
# Out:
# Digite um número: 2
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20

# %% [markdown]
# **Desafio 010 - Conversor de moedas**
#
# Crie um programa que leia quanto dinheiro uma pessoa tem na carteira e mostre quantos dólares ela pode comprar (consideara US$ 1 = $$3,27)

# %%
real = float(input('Valor na carteira R$ '))
dolar = 3.27
cambio = real / dolar
print(f'É possível comprar U$ {cambio:.2f}')
# Out:
# Valor na carteira R$ 1
# É possível comprar U$ 0.31

# %% [markdown]
# **Desafio 011 - Pintando parede**
#
# Faça um program que leia a largura e a altura de uma parede em metros, calcule a sua área e a quantidade de tinta becessária para pintá-la, sabendo que cada litro de tinta pinta uma área de 2m quadrados.

# %%
largura = float(input('Digite a largura em metros: '))
altura = float(input('Digite a altura em metros: '))
area = largura * altura
litros = area / 2
print(f'Área de {area}m². Serão necessários {litros} litros de tinta.')
# Out:
# Digite a largura em metros: 2
# Digite a altura em metros: 2
# Área de 4.0m². Serão necessários 2.0 litros de tinta.

# %% [markdown]
# **Desafio 012 - Calculando descontos**
#
# Faça um algoritmo que leia o preço de um produto e mostre seu novo preço com 5% de desconto.

# %%
preco = float(input('Digite o preço do produto: R$'))
novo_preco = preco * (1 - 5/100)
print(f'Preço com desconto: R${novo_preco:.2f}')
# Out:
# Digite o preço do produto: R$10.53
# Preço com desconto: R$10.00

# %% [markdown]
# **Desafio 013 - Reajuste salarial**
#
# Faça um algoritmo que leia o salário de um funcionário e mostre seu novo salário, com 15% de aumento.

# %%
salario = float(input('Digite o valor do salário: R$'))
aumento = salario * (1 + 15/100)
print(f'Aummento de 15% equivame a R${aumento:.2f}')
# Out:
# Digite o valor do salário: R$200
# Aummento de 15% equivame a R$230.00

# %% [markdown]
# **Desafio 014 - Conversor de temperatura**
#
# Escreva um programa que converta uma temperatura digitada em ºC oara ºF

# %%
celsius = float(input('Digite uma temperatura em ºC: '))
fahrenheit = 9 * celsius / 5 + 32
print(f'A temperatura {celsius}ºC corrresponde à {fahrenheit}ºF')
# Out:
# Digite uma temperatura em ºC: 40
# A temperatura 40.0ºC corrresponde à 104.0ºF

# %% [markdown]
# **Deafio 015 - Aluguem de carros**
#
# Escreva um programa que pergunte a quantidade de Km percorridos por um carro alugado e a quantidade de dias pelos quais ele foi alugado. Calcule o preço a pagar, sabendo que o carro custa 'R$ 60' por dia e 'R$ 0,15' por Km rodado.

# %%
km_percorrido = float(input('Digite a quantidade de KM percorridos: '))
qtde_dias = int(input('Digite a quantidade de dias do aluguel: '))
custo = (qtde_dias * 60) + (km_percorrido * 0.15)
print(f'O aluguel do carro vai custar R$ {custo}')
# Out:
# Digite a quantidade de KM percorridos: 350
# Digite a quantidade de dias do aluguel: 3
# O aluguel do carro vai custar R$ 232.5

# %% [markdown]
# **Desafio 016 - Qebrando um número**
#
# Crie um programa que leia um número Real qualquer pelo teclado e mostre na tela a usa porção inteira.

# %%
import math
num = float(input('Digite um número: '))
print(f'A porção inteira é {math.floor(num)}')
# Out:
# Digite um número: 3.1543536565346546523424
# A porção inteira é 3

# %% [markdown]
# **Desafio 017 - Catetos e hipotenusa**
#
# Faça um programa que leia o cumprimento do cateto oposto e do cateto adjacente de um triângulo retângulo, calcule e mostre o cumprimento da hipotenusa.

# %%
import math
oposto = float(input("Digite o valor do cateto oposto: "))
adjacente = float(input("Digite o valor do cateto adjacente: "))
print(f'Hipotenusa 1: {math.hypot(oposto, adjacente)}')
# Out:
# Digite o valor do cateto oposto: 2
# Digite o valor do cateto adjacente: 2
# Hipotenusa 1: 2.8284271247461903

# %% [markdown]
# **Desafio 018 - Seno, cosseno e tangente**
#
# Faça um programa que leia um ângulo qualquer e mostre na tela o valor do seno, cosseno e tangente desse ângulo.

# %%
angulo = math.radians(float(input('Digite a medida do ângulo: ')))
print(f'Seno: {math.sin(angulo):.5f}')
print(f'Cosseno: {math.cos(angulo):.5f}')
print(f'Tangente: {math.tan(angulo):.5f}')
# Out:
# Digite a medida do ângulo: 2
# Seno: 0.03490
# Cosseno: 0.99939
# Tangente: 0.03492

# %% [markdown]
# **Desafio 019 - Sorteando um item na listas**
#
# Um professor quer sortear um dos seus quatro alunos para apagar o quadro. Faça um programa que ajude ele, lendo o nome deles e escrevendo o nome do escolhido.

# %%
import random
alunos = [input('Aluno 1: '), input('Aluno 2: '), input('Aluno 3: '), input('Aluno 4: ')]
print(f'Escolhido: {alunos[random.randrange(3)]}')
# Out:
# Aluno 1: a
# Aluno 2: b
# Aluno 3: c
# Aluno 4: d
# Escolhido: c

# %% [markdown]
# **Desafio 020 - Sorteando uma ordem na lissta**
#
# O mesmo profeddor do desafio anterior quer sortear a ordem de apresentação dos trabalhos dos alunos. Faça um programa que leia o nome dos quatro alunos e mostre a ordem sorteada.

# %% [markdown]
# **Desafio 021 - Tocando um MP3**
#
# Faça um programa em Python que abra e reproduza o áudio de um arquivo MP3.
