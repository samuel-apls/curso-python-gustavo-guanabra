# %% [markdown]
# <a href="https://colab.research.google.com/github/samuel-apls/curso-python-gustavo-guanabra/blob/main/Python_Mundo_1_Exerc%C3%ADcios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ex000**
#
# Exercício de exemplo

# %%
print('Olá, Mundo!')

# %% [markdown]
# **ex001**
#
# Crie um programa que escreva "Olá, Mundo!" na tela.

# %%
msg = 'Olá, Mundo!'
print(msg)

# %% [markdown]
# **ex002**
#
# Faça um programa que leia o nome de uma pessoa e mostra uma mensagem de boas-vindas.

# %%
nome = input('Digite seu nome: ')
print('Olá, {}! Seja muito bem vindo'.format(nome))

# %% [markdown]
# **ex003**
#
# Crie um programa que leia dois numeros e mostra a soma entre eles.

# %%
n1 = int(input('Digite um número: '))
n2 = int(input('Digite outro número: '))
print('A soma entre {} e {} é igual a {}'.format(n1, n2, n1 + n2))
